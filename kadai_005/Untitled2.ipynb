# %%
user_names = ["侍太郎", "侍一郎", "侍二郎", "侍三郎"]

# %%
print(user_names[1])
user_names.append("侍五郎")
print(user_names)
# Out:
# 侍一郎
# ['侍太郎', '侍一郎', '侍二郎', '侍三郎', '侍五郎']

# %%
upper_base = 10  # 上辺
lower_base = 20  # 下辺
height = 5       # 高さ
area = (upper_base + lower_base) * height / 2
print(f"{area:g}cm²")
# Out:
# 75cm²
